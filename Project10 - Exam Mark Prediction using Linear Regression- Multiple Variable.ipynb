# %% [markdown]
# #### Project Title: Exam Mark Prediction using Linear Regression - Multiple Variables
#
# #### Objectives: Predicting Exam mark based on hours, age and Internet availability

# %% [markdown]
# #### *Importing Libraries*

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### *Loading Dataset*

# %%
dataset = pd.read_csv('data1.csv')
dataset
# Out:
#      hours  age  internet  marks
# 0     6.83   15         1  78.50
# 1     6.56   16         0  76.74
# 2      NaN   17         1  78.68
# 3     5.67   18         0  71.82
# 4     8.67   19         1  84.19
# ..     ...  ...       ...    ...
# 196   8.56   19         1  84.68
# 197   8.94   20         1  86.75
# 198   6.60   15         1  78.05
# 199   8.35   16         1  83.50
# 200   4.15   15         0  81.45
#
# [201 rows x 4 columns]

# %% [markdown]
# #### *Summarizing Dataset*

# %%
print(dataset.shape)
print(dataset.head(5))
# Out:
# (201, 4)
#    hours  age  internet  marks
# 0   6.83   15         1  78.50
# 1   6.56   16         0  76.74
# 2    NaN   17         1  78.68
# 3   5.67   18         0  71.82
# 4   8.67   19         1  84.19

# %% [markdown]
# #### *Finding & Removing NA values from our Features X*

# %%
dataset.columns[dataset.isna().any()]
# Out:
# Index(['hours'], dtype='object')

# %%
dataset.hours = dataset.hours.fillna(dataset.hours.mean())

# %% [markdown]
# #### *Recheck for NA values*

# %%
dataset.columns[dataset.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# #### *Segregate Dataset into Input X & Output Y*

# %%
#X = dataset.iloc[:, :-1].values

X=dataset.drop('marks', axis='columns')
print(X.shape)
print(X)
# Out:
# (201, 3)
#         hours  age  internet
# 0    6.830000   15         1
# 1    6.560000   16         0
# 2    6.981429   17         1
# 3    5.670000   18         0
# 4    8.670000   19         1
# ..        ...  ...       ...
# 196  8.560000   19         1
# 197  8.940000   20         1
# 198  6.600000   15         1
# 199  8.350000   16         1
# 200  4.150000   15         0
#
# [201 rows x 3 columns]

# %%
#Y = dataset.iloc[:, -1].values

Y=dataset.marks
Y
# Out:
# 0      78.50
# 1      76.74
# 2      78.68
# 3      71.82
# 4      84.19
#        ...
# 196    84.68
# 197    86.75
# 198    78.05
# 199    83.50
# 200    81.45
# Name: marks, Length: 201, dtype: float64

# %% [markdown]
# #### *Training Dataset using Linear Regression*

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# #### *Predicted mark using custom values*

# %%
a=[[6.2,20,1]]
PredictedmodelResult = model.predict(a)
print(PredictedmodelResult)
# Out:
# [74.93386134]
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
#plt.scatter(X,Y, color="red")
plt.plot(X.age,Y)
plt.title("Linear Regression")
plt.xlabel("Age")
plt.ylabel("marks")
plt.grid()
plt.show()
